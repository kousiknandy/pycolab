# %% [markdown]
# <a href="https://colab.research.google.com/github/kousiknandy/pycolab/blob/main/SimpleWiki_Related_Asyncio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import aiohttp
import asyncio

class AWikiCrawler:
  def __init__(self, url):
    self.url = url
    self.host = "https://simple.wikipedia.org"

  async def next_urls(self):
    async with aiohttp.ClientSession() as session:
      async with session.get(self.host + self.url) as resp:
        self.data = await resp.text()
    soup = BeautifulSoup(self.data, "html.parser")
    if not (h2 := soup.find(id="Related_pages")):
      return None
    rl = h2.parent.next_siblings
    _ = next(rl)
    ul = next(rl)
    links = ul.find_all("a")
    return [l["href"] for l in links if l["href"].startswith("/wiki/")]

# %%
async def scrape(url, depth):
  w = AWikiCrawler(url)
  print("Visiting", depth, url)
  return await w.next_urls()

async def main(seed_url):
  depth = 0
  url_queue = [seed_url]
  visited_urls = set()
  while url_queue:
    ws = [asyncio.create_task(scrape(u,depth)) for u in url_queue]
    url_queue = []
    depth += 1
    for w in asyncio.as_completed(ws):
      new_urls = await w
      print("next", new_urls)
      if not new_urls: continue
      if depth > 5 or len(visited_urls) > 150: continue
      for u in new_urls:
        if u in visited_urls: continue
        visited_urls.add(u)
        url_queue.append(u)

  print("Overall visited", len(visited_urls), visited_urls)

await main("/wiki/Computer_science")
# Out:
# Visiting 0 /wiki/Computer_science
# next ['/wiki/Computing', '/wiki/Formal_language', '/wiki/Turing_Award', '/wiki/Computer_jargon', '/wiki/List_of_words_about_computers']
# Visiting 1 /wiki/Computing
# Visiting 1 /wiki/Formal_language
# Visiting 1 /wiki/Turing_Award
# Visiting 1 /wiki/Computer_jargon
# Visiting 1 /wiki/List_of_words_about_computers
# next None
# next None
# next None
# next ['/wiki/Computing', '/wiki/Formal_language', '/wiki/Turing_Award', '/wiki/Computer_jargon', '/wiki/List_of_words_about_computers']
# next ['/wiki/Language', '/wiki/Syntax', '/wiki/Semantics', '/wiki/Natural_language', '/wiki/Computer_language', '/wiki/Programming_language']
# Visiting 2 /wiki/Language
# Visiting 2 /wiki/Syntax
# Visiting 2 /wiki/Semantics
# Visiting 2 /wiki/Natural_language
# Visiting 2 /wiki/Computer_language
# Visiting 2 /wiki/Programming_language
# next ['/wiki/Artificial_language', '/wiki/Formal_language', '/wiki/Natural_language_processing']
# next ['/wiki/Algorithm', '/wiki/Formal_language', '/wiki/List_of_programming_languages', '/wiki/Programmer', '/wiki/Compiler', '/wiki/Computer_programming', '/wiki/Programming_paradigm', '/wiki/Pseudocode']
# next ['/wiki/Phrase', '/wiki/Grammar']
# next None
# next ['/wiki/Algorithm', '/wiki/Formal_language', '/wiki/List_of_programming_languages', '/wiki/Programmer', '/wiki/Compiler', '/wiki/Computer_programming', '/wiki/Programming_paradigm', '/wiki/Pseudocode']
# next []
# Visiting 3 /wiki/Artificial_language
# Visiting 3 /wiki/Natural_language_processing
# Visiting 3 /wiki/Algorithm
# Visiting 3 /wiki/List_of_programming_languages
# Visiting 3 /wiki/Programmer
# Visiting 3 /wiki/Compiler
# Visiting 3 /wiki/Computer_programming
# Visiting 3 /wiki/Programming_paradigm
# Visiting 3 /wiki/Pseudocode
# Visiting 3 /wiki/Phrase
# Visiting 3 /wiki/Grammar
# next None
# next ['/wiki/Constructed_language', '/wiki/Natural_language', '/wiki/Computer_language']
# next None
# next ['/wiki/Euclidean_algorithm', '/wiki/Greatest_common_divisor', '/wiki/Numerical_analysis']
# next None
# next None
# next ['/wiki/Hebrew', '/wiki/Linguistics', '/wiki/Greek_alphabet', '/wiki/Iranic_languages', '/wiki/List_of_languages', '/wiki/Hebrew_alphabet', '/wiki/Japonic_languages', '/wiki/Phoenician_alphabet', '/wiki/Afro-Asiatic_languages', '/wiki/Indo-Iranian_languages', '/wiki/Sino-Tibetan_languages', '/wiki/Indo-European_languages']
# next []
# next None
# next None
# next None
# Visiting 4 /wiki/Constructed_language
# Visiting 4 /wiki/Euclidean_algorithm
# Visiting 4 /wiki/Greatest_common_divisor
# Visiting 4 /wiki/Numerical_analysis
# Visiting 4 /wiki/Hebrew
# Visiting 4 /wiki/Linguistics
# Visiting 4 /wiki/Greek_alphabet
# Visiting 4 /wiki/Iranic_languages
# Visiting 4 /wiki/List_of_languages
# Visiting 4 /wiki/Hebrew_alphabet
# Visiting 4 /wiki/Japonic_languages
# Visiting 4 /wiki/Phoenician_alphabet
# Visiting 4 /wiki/Afro-Asiatic_languages
# Visiting 4 /wiki/Indo-Iranian_languages
# Visiting 4 /wiki/Sino-Tibetan_languages
# Visiting 4 /wiki/Indo-European_languages
# next None
# next None
# next ['/wiki/Wikipedia:Sister_projects']
# next None
# next None
# next ['/wiki/Ancient_Greek_language', '/wiki/Greek_language', '/wiki/History_of_the_alphabet']
# next ['/wiki/Coprime', '/wiki/Euclid%27s_Elements', '/wiki/Least_common_multiple']
# next ['/wiki/Phoenician_alphabet']
# next ['/wiki/Language', '/wiki/Constructed_language', '/wiki/List_of_fictional_languages', '/wiki/List_of_programming_languages', '/wiki/Sign_language']
# next ['/wiki/Phoenician_alphabet']
# next None
# next ['/wiki/Chinese_language']
# next None
# next None
# next None
# next None
# Visiting 5 /wiki/Wikipedia:Sister_projects
# Visiting 5 /wiki/Ancient_Greek_language
# Visiting 5 /wiki/Greek_language
# Visiting 5 /wiki/History_of_the_alphabet
# Visiting 5 /wiki/Coprime
# Visiting 5 /wiki/Euclid%27s_Elements
# Visiting 5 /wiki/Least_common_multiple
# Visiting 5 /wiki/List_of_fictional_languages
# Visiting 5 /wiki/Sign_language
# Visiting 5 /wiki/Chinese_language
# next ['/wiki/Greek_alphabet', '/wiki/Greek_language']
# next ['/wiki/Standard_Chinese', '/wiki/Mandarin_Chinese', '/wiki/Cantonese_language']
# next ['/wiki/Chinese_remainder_theorem', '/wiki/Euler%27s_totient_function', '/wiki/Euler%27s_totient_theorem']
# next None
# next ['/wiki/American_Sign_Language', '/wiki/Deaf']
# next None
# next ['/wiki/Scalar', '/wiki/Algebra', '/wiki/Arithmetic', '/wiki/Pure_mathematics', '/wiki/Mathematical_analysis', '/wiki/Greatest_common_divisor']
# next ['/wiki/Greek_numbers']
# next None
# next None
# Overall visited 48 {'/wiki/List_of_languages', '/wiki/Formal_language', '/wiki/History_of_the_alphabet', '/wiki/List_of_fictional_languages', '/wiki/Euclid%27s_Elements', '/wiki/Chinese_language', '/wiki/Programming_paradigm', '/wiki/Sign_language', '/wiki/Syntax', '/wiki/Artificial_language', '/wiki/Euclidean_algorithm', '/wiki/Linguistics', '/wiki/Hebrew_alphabet', '/wiki/Least_common_multiple', '/wiki/Turing_Award', '/wiki/Afro-Asiatic_languages', '/wiki/Computer_programming', '/wiki/List_of_programming_languages', '/wiki/Hebrew', '/wiki/Computer_language', '/wiki/Coprime', '/wiki/Phoenician_alphabet', '/wiki/List_of_words_about_computers', '/wiki/Greatest_common_divisor', '/wiki/Indo-Iranian_languages', '/wiki/Ancient_Greek_language', '/wiki/Compiler', '/wiki/Programmer', '/wiki/Grammar', '/wiki/Natural_language', '/wiki/Sino-Tibetan_languages', '/wiki/Natural_language_processing', '/wiki/Algorithm', '/wiki/Computer_jargon', '/wiki/Programming_language', '/wiki/Iranic_languages', '/wiki/Japonic_languages', '/wiki/Greek_language', '/wiki/Numerical_analysis', '/wiki/Indo-European_languages', '/wiki/Computing', '/wiki/Greek_alphabet', '/wiki/Phrase', '/wiki/Constructed_language', '/wiki/Language', '/wiki/Pseudocode', '/wiki/Wikipedia:Sister_projects', '/wiki/Semantics'}
