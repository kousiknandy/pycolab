# %% [markdown]
# <a href="https://colab.research.google.com/github/kousiknandy/pycolab/blob/main/SimpleWiki_AsyncIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import aiohttp
import asyncio

class AWikiCrawler:
    def __init__(self, url):
        self.url = url
        self.host = "https://simple.wikipedia.org"

    async def next_urls(self):
        async with aiohttp.ClientSession() as session:
            async with session.get(self.host + self.url) as resp:
                self.data = await resp.text()
        soup = BeautifulSoup(self.data, "html.parser")
        if not (h2 := soup.find(id="Related_pages")): return None
        rl = h2.find_parent().find_next_siblings()
        for r in rl:
            # print(type(r), r)
            if r.name == "ul" or  r.find("ul"):
                links = r.find_all("a")
                # print(links)
                return [l["href"] for l in links if l["href"].startswith("/wiki/")]



async def scrape(url, depth):
    w = AWikiCrawler(url)
    print("Visiting", depth, url)
    await asyncio.sleep(0.3333333)
    return depth, await w.next_urls()

async def main(seed_url):
    url_queue = [(seed_url, 0)]
    visited_urls = set()
    pending = set()
    while url_queue or pending:
        if url_queue:
            new_tsk = [asyncio.create_task(scrape(u,d)) for u,d in url_queue]
        url_queue = []
        tsk = list(pending) + new_tsk
        done, pending = await asyncio.wait(tsk, return_when=asyncio.FIRST_COMPLETED)
        for w in done:
            depth, new_urls = await w
            print("next", new_urls)
            if not new_urls: continue
            if depth > 5 or len(visited_urls) > 50:
                continue
            for u in new_urls:
                if u in visited_urls:
                    print("Already visited", u)
                    continue
                visited_urls.add(u)
                url_queue.append((u,depth+1))

    print("Overall visited", len(visited_urls), visited_urls)

await main("/wiki/Computer_science")
await main("/wiki/Language")
# Out:
# Visiting 0 /wiki/Computer_science
# next ['/wiki/Computing', '/wiki/Formal_language', '/wiki/Turing_Award', '/wiki/Computer_jargon', '/wiki/List_of_words_about_computers']
# Visiting 1 /wiki/Computing
# Visiting 1 /wiki/Formal_language
# Visiting 1 /wiki/Turing_Award
# Visiting 1 /wiki/Computer_jargon
# Visiting 1 /wiki/List_of_words_about_computers
# next None
# next None
# next ['/wiki/Language', '/wiki/Syntax', '/wiki/Semantics', '/wiki/Natural_language', '/wiki/Computer_language', '/wiki/Programming_language']
# next ['/wiki/Computing', '/wiki/Formal_language', '/wiki/Turing_Award', '/wiki/Computer_jargon', '/wiki/List_of_words_about_computers']
# Already visited /wiki/Computing
# Already visited /wiki/Formal_language
# Already visited /wiki/Turing_Award
# Already visited /wiki/Computer_jargon
# Already visited /wiki/List_of_words_about_computers
# next None
# Visiting 2 /wiki/Language
# Visiting 2 /wiki/Syntax
# Visiting 2 /wiki/Semantics
# Visiting 2 /wiki/Natural_language
# Visiting 2 /wiki/Computer_language
# Visiting 2 /wiki/Programming_language
# next None
# next ['/wiki/Artificial_language', '/wiki/Formal_language', '/wiki/Natural_language_processing']
# Already visited /wiki/Formal_language
# Visiting 3 /wiki/Artificial_language
# Visiting 3 /wiki/Natural_language_processing
# next ['/wiki/Alphabet', '/wiki/Basic_English', '/wiki/Sign_language', '/wiki/English_as_a_foreign_language', '/wiki/English_language', '/wiki/Historical_linguistics', '/wiki/Language_families_and_languages', '/wiki/Linguistics', '/wiki/List_of_languages', '/wiki/Orthography', '/wiki/Phonology', '/wiki/Second_language', '/wiki/Semantics', '/wiki/Chinese_language', '/wiki/Template:Languages_of_Countries', '/wiki/Template_talk:Languages_of_Countries', '/wiki/Languages_of_Morocco', '/wiki/Languages_of_Nigeria', '/wiki/Languages_of_South_Africa', '/wiki/Languages_of_Canada', '/wiki/Languages_of_Afghanistan', '/wiki/Languages_of_India', '/wiki/Languages_of_Iran', '/wiki/Languages_of_Japan', '/wiki/Languages_of_Pakistan', '/wiki/Languages_of_Singapore', '/wiki/Languages_of_Andorra', '/wiki/Languages_of_Ireland', '/wiki/Languages_of_Malta', '/wiki/Languages_of_Russia', '/wiki/Languages_of_Spain', '/wiki/Languages_of_Australia', '/wiki/Languages_of_New_Zealand', '/wiki/Languages_of_Papua_New_Guinea']
# Already visited /wiki/Semantics
# next None
# next ['/wiki/Algorithm', '/wiki/Formal_language', '/wiki/List_of_programming_languages', '/wiki/Programmer', '/wiki/Compiler', '/wiki/Computer_programming', '/wiki/Programming_paradigm', '/wiki/Pseudocode']
# Already visited /wiki/Formal_language
# next ['/wiki/Phrase', '/wiki/Grammar']
# next ['/wiki/Algorithm', '/wiki/Formal_language', '/wiki/List_of_programming_languages', '/wiki/Programmer', '/wiki/Compiler', '/wiki/Computer_programming', '/wiki/Programming_paradigm', '/wiki/Pseudocode']
# Visiting 3 /wiki/Alphabet
# Visiting 3 /wiki/Basic_English
# Visiting 3 /wiki/Sign_language
# Visiting 3 /wiki/English_as_a_foreign_language
# Visiting 3 /wiki/English_language
# Visiting 3 /wiki/Historical_linguistics
# Visiting 3 /wiki/Language_families_and_languages
# Visiting 3 /wiki/Linguistics
# Visiting 3 /wiki/List_of_languages
# Visiting 3 /wiki/Orthography
# Visiting 3 /wiki/Phonology
# Visiting 3 /wiki/Second_language
# Visiting 3 /wiki/Chinese_language
# Visiting 3 /wiki/Template:Languages_of_Countries
# Visiting 3 /wiki/Template_talk:Languages_of_Countries
# Visiting 3 /wiki/Languages_of_Morocco
# Visiting 3 /wiki/Languages_of_Nigeria
# Visiting 3 /wiki/Languages_of_South_Africa
# Visiting 3 /wiki/Languages_of_Canada
# Visiting 3 /wiki/Languages_of_Afghanistan
# Visiting 3 /wiki/Languages_of_India
# Visiting 3 /wiki/Languages_of_Iran
# Visiting 3 /wiki/Languages_of_Japan
# Visiting 3 /wiki/Languages_of_Pakistan
# Visiting 3 /wiki/Languages_of_Singapore
# Visiting 3 /wiki/Languages_of_Andorra
# Visiting 3 /wiki/Languages_of_Ireland
# Visiting 3 /wiki/Languages_of_Malta
# Visiting 3 /wiki/Languages_of_Russia
# Visiting 3 /wiki/Languages_of_Spain
# Visiting 3 /wiki/Languages_of_Australia
# Visiting 3 /wiki/Languages_of_New_Zealand
# Visiting 3 /wiki/Languages_of_Papua_New_Guinea
# Visiting 3 /wiki/Algorithm
# Visiting 3 /wiki/List_of_programming_languages
# Visiting 3 /wiki/Programmer
# Visiting 3 /wiki/Compiler
# Visiting 3 /wiki/Computer_programming
# Visiting 3 /wiki/Programming_paradigm
# Visiting 3 /wiki/Pseudocode
# next ['/wiki/Constructed_language', '/wiki/Natural_language', '/wiki/Computer_language']
# next None
# next ['/wiki/Received_Pronunciation']
# next ['/wiki/Simplified_English', '/wiki/Fran%C3%A7ais_fondamental', '/wiki/Plain_English_Campaign', '/wiki/Wikipedia:Basic_English_ordered_wordlist', '/wiki/International_auxiliary_language', '/wiki/Wikipedia:Basic_English_picture_wordlist', '/wiki/Wikipedia:Basic_English_combined_wordlist', '/wiki/Wikipedia:Basic_English_compound_wordlist', '/wiki/Wikipedia:Basic_English_alphabetical_wordlist', '/wiki/Wikipedia:List_of_simple_verbs', '/wiki/Wikipedia:List_of_simple_adjectives', '/wiki/Wikipedia:Basic_English_international_wordlist']
# next ['/wiki/ELTon_Award']
# next ['/wiki/Multialphabetism', '/wiki/Writing']
# next ['/wiki/American_Sign_Language', '/wiki/Deaf']
# next ['/wiki/Euclidean_algorithm', '/wiki/Greatest_common_divisor', '/wiki/Numerical_analysis']
# next ['/wiki/Simplified_English', '/wiki/Fran%C3%A7ais_fondamental', '/wiki/Plain_English_Campaign', '/wiki/Wikipedia:Basic_English_ordered_wordlist', '/wiki/International_auxiliary_language', '/wiki/Wikipedia:Basic_English_picture_wordlist', '/wiki/Wikipedia:Basic_English_combined_wordlist', '/wiki/Wikipedia:Basic_English_compound_wordlist', '/wiki/Wikipedia:Basic_English_alphabetical_wordlist', '/wiki/Wikipedia:List_of_simple_verbs', '/wiki/Wikipedia:List_of_simple_adjectives', '/wiki/Wikipedia:Basic_English_international_wordlist']
# next None
# next None
# next None
# next None
# next None
# next ['/wiki/Vatican', '/wiki/Monaco', '/wiki/San_Marino', '/wiki/Lichtenstein', '/wiki/List_of_rivers_of_Andorra', '/wiki/Constitutional_monarchy', '/wiki/Andorra_at_the_Olympics']
# next None
# next None
# next None
# next None
# next ['/wiki/Multialphabetism', '/wiki/Writing']
# next None
# next ['/wiki/Languages_of_Australia', '/wiki/Languages_of_Papua_New_Guinea']
# next None
# next None
# next None
# next None
# next ['/wiki/Standard_Chinese', '/wiki/Mandarin_Chinese', '/wiki/Cantonese_language']
# next None
# next None
# next ['/wiki/Languages_of_New_Zealand', '/wiki/Languages_of_Australia']
# next ['/wiki/Mindset', '/wiki/Turing_completeness']
# next ['/wiki/Ghoti']
# next None
# next ['/wiki/ELTon_Award']
# next None
# next ['/wiki/Languages_of_South_Asia']
# next None
# next None
# next None
# next ['/wiki/Language', '/wiki/Constructed_language', '/wiki/List_of_fictional_languages', '/wiki/List_of_programming_languages', '/wiki/Sign_language']
# next ['/wiki/American_Sign_Language', '/wiki/Deaf']
# next ['/wiki/Received_Pronunciation']
# next None
# next None
# next ['/wiki/English_Language', '/wiki/Malay_language', '/wiki/Mandarin_Chinese', '/wiki/Singlish', '/wiki/Tamil_language']
# next None
# next ['/wiki/Languages_of_New_Zealand', '/wiki/Languages_of_Papua_New_Guinea']
# Overall visited 53 {'/wiki/Phonology', '/wiki/Natural_language_processing', '/wiki/Chinese_language', '/wiki/Languages_of_Andorra', '/wiki/Programmer', '/wiki/Languages_of_Morocco', '/wiki/Pseudocode', '/wiki/English_as_a_foreign_language', '/wiki/Syntax', '/wiki/Orthography', '/wiki/Languages_of_Canada', '/wiki/Languages_of_Russia', '/wiki/Languages_of_South_Africa', '/wiki/Languages_of_Spain', '/wiki/Languages_of_New_Zealand', '/wiki/Languages_of_Papua_New_Guinea', '/wiki/Second_language', '/wiki/Template_talk:Languages_of_Countries', '/wiki/Language_families_and_languages', '/wiki/Languages_of_Pakistan', '/wiki/Semantics', '/wiki/Historical_linguistics', '/wiki/Sign_language', '/wiki/Basic_English', '/wiki/Linguistics', '/wiki/Computer_programming', '/wiki/Languages_of_Malta', '/wiki/Computer_language', '/wiki/Turing_Award', '/wiki/Languages_of_Ireland', '/wiki/List_of_programming_languages', '/wiki/Alphabet', '/wiki/List_of_languages', '/wiki/Languages_of_Nigeria', '/wiki/Computing', '/wiki/Programming_language', '/wiki/Artificial_language', '/wiki/Programming_paradigm', '/wiki/Languages_of_Iran', '/wiki/Languages_of_India', '/wiki/Compiler', '/wiki/Languages_of_Japan', '/wiki/Natural_language', '/wiki/Algorithm', '/wiki/List_of_words_about_computers', '/wiki/Formal_language', '/wiki/Template:Languages_of_Countries', '/wiki/Languages_of_Afghanistan', '/wiki/English_language', '/wiki/Languages_of_Singapore', '/wiki/Language', '/wiki/Languages_of_Australia', '/wiki/Computer_jargon'}
# Visiting 0 /wiki/Language
# next ['/wiki/Alphabet', '/wiki/Basic_English', '/wiki/Sign_language', '/wiki/English_as_a_foreign_language', '/wiki/English_language', '/wiki/Historical_linguistics', '/wiki/Language_families_and_languages', '/wiki/Linguistics', '/wiki/List_of_languages', '/wiki/Orthography', '/wiki/Phonology', '/wiki/Second_language', '/wiki/Semantics', '/wiki/Chinese_language', '/wiki/Template:Languages_of_Countries', '/wiki/Template_talk:Languages_of_Countries', '/wiki/Languages_of_Morocco', '/wiki/Languages_of_Nigeria', '/wiki/Languages_of_South_Africa', '/wiki/Languages_of_Canada', '/wiki/Languages_of_Afghanistan', '/wiki/Languages_of_India', '/wiki/Languages_of_Iran', '/wiki/Languages_of_Japan', '/wiki/Languages_of_Pakistan', '/wiki/Languages_of_Singapore', '/wiki/Languages_of_Andorra', '/wiki/Languages_of_Ireland', '/wiki/Languages_of_Malta', '/wiki/Languages_of_Russia', '/wiki/Languages_of_Spain', '/wiki/Languages_of_Australia', '/wiki/Languages_of_New_Zealand', '/wiki/Languages_of_Papua_New_Guinea']
# Visiting 1 /wiki/Alphabet
# Visiting 1 /wiki/Basic_English
# Visiting 1 /wiki/Sign_language
# Visiting 1 /wiki/English_as_a_foreign_language
# Visiting 1 /wiki/English_language
# Visiting 1 /wiki/Historical_linguistics
# Visiting 1 /wiki/Language_families_and_languages
# Visiting 1 /wiki/Linguistics
# Visiting 1 /wiki/List_of_languages
# Visiting 1 /wiki/Orthography
# Visiting 1 /wiki/Phonology
# Visiting 1 /wiki/Second_language
# Visiting 1 /wiki/Semantics
# Visiting 1 /wiki/Chinese_language
# Visiting 1 /wiki/Template:Languages_of_Countries
# Visiting 1 /wiki/Template_talk:Languages_of_Countries
# Visiting 1 /wiki/Languages_of_Morocco
# Visiting 1 /wiki/Languages_of_Nigeria
# Visiting 1 /wiki/Languages_of_South_Africa
# Visiting 1 /wiki/Languages_of_Canada
# Visiting 1 /wiki/Languages_of_Afghanistan
# Visiting 1 /wiki/Languages_of_India
# Visiting 1 /wiki/Languages_of_Iran
# Visiting 1 /wiki/Languages_of_Japan
# Visiting 1 /wiki/Languages_of_Pakistan
# Visiting 1 /wiki/Languages_of_Singapore
# Visiting 1 /wiki/Languages_of_Andorra
# Visiting 1 /wiki/Languages_of_Ireland
# Visiting 1 /wiki/Languages_of_Malta
# Visiting 1 /wiki/Languages_of_Russia
# Visiting 1 /wiki/Languages_of_Spain
# Visiting 1 /wiki/Languages_of_Australia
# Visiting 1 /wiki/Languages_of_New_Zealand
# Visiting 1 /wiki/Languages_of_Papua_New_Guinea
# next ['/wiki/Simplified_English', '/wiki/Fran%C3%A7ais_fondamental', '/wiki/Plain_English_Campaign', '/wiki/Wikipedia:Basic_English_ordered_wordlist', '/wiki/International_auxiliary_language', '/wiki/Wikipedia:Basic_English_picture_wordlist', '/wiki/Wikipedia:Basic_English_combined_wordlist', '/wiki/Wikipedia:Basic_English_compound_wordlist', '/wiki/Wikipedia:Basic_English_alphabetical_wordlist', '/wiki/Wikipedia:List_of_simple_verbs', '/wiki/Wikipedia:List_of_simple_adjectives', '/wiki/Wikipedia:Basic_English_international_wordlist']
# next None
# next ['/wiki/English_Language', '/wiki/Malay_language', '/wiki/Mandarin_Chinese', '/wiki/Singlish', '/wiki/Tamil_language']
# next None
# next None
# next ['/wiki/ELTon_Award']
# next ['/wiki/American_Sign_Language', '/wiki/Deaf']
# next None
# next None
# next ['/wiki/Multialphabetism', '/wiki/Writing']
# next None
# next None
# next None
# next None
# next None
# next None
# next None
# Visiting 2 /wiki/Simplified_English
# Visiting 2 /wiki/Fran%C3%A7ais_fondamental
# Visiting 2 /wiki/Plain_English_Campaign
# Visiting 2 /wiki/Wikipedia:Basic_English_ordered_wordlist
# Visiting 2 /wiki/International_auxiliary_language
# Visiting 2 /wiki/Wikipedia:Basic_English_picture_wordlist
# Visiting 2 /wiki/Wikipedia:Basic_English_combined_wordlist
# Visiting 2 /wiki/Wikipedia:Basic_English_compound_wordlist
# Visiting 2 /wiki/Wikipedia:Basic_English_alphabetical_wordlist
# Visiting 2 /wiki/Wikipedia:List_of_simple_verbs
# Visiting 2 /wiki/Wikipedia:List_of_simple_adjectives
# Visiting 2 /wiki/Wikipedia:Basic_English_international_wordlist
# Visiting 2 /wiki/English_Language
# Visiting 2 /wiki/Malay_language
# Visiting 2 /wiki/Mandarin_Chinese
# Visiting 2 /wiki/Singlish
# Visiting 2 /wiki/Tamil_language
# next ['/wiki/Standard_Chinese', '/wiki/Mandarin_Chinese', '/wiki/Cantonese_language']
# next None
# next ['/wiki/Language', '/wiki/Constructed_language', '/wiki/List_of_fictional_languages', '/wiki/List_of_programming_languages', '/wiki/Sign_language']
# next None
# next ['/wiki/Received_Pronunciation']
# next ['/wiki/Vatican', '/wiki/Monaco', '/wiki/San_Marino', '/wiki/Lichtenstein', '/wiki/List_of_rivers_of_Andorra', '/wiki/Constitutional_monarchy', '/wiki/Andorra_at_the_Olympics']
# next None
# next ['/wiki/Languages_of_South_Asia']
# next ['/wiki/Languages_of_New_Zealand', '/wiki/Languages_of_Papua_New_Guinea']
# next ['/wiki/Languages_of_New_Zealand', '/wiki/Languages_of_Australia']
# next ['/wiki/Ghoti']
# next ['/wiki/Languages_of_Australia', '/wiki/Languages_of_Papua_New_Guinea']
# next None
# next None
# next None
# next None
# next None
# next None
# next ['/wiki/Basic_English']
# next None
# next None
# next ['/wiki/Wikipedia:Word_frequency', '/wiki/Wikipedia:Basic_English_alphabetical_wordlist', '/wiki/Commonly_misspelled_words', '/wiki/Glossary']
# next None
# next ['/wiki/Wikipedia:BASIC_English_ordered_wordlist', '/wiki/Wikipedia:BASIC_English_combined_wordlist', '/wiki/Wikipedia:BASIC_English_international_wordlist', '/wiki/BASIC_English', '/wiki/Charles_Kay_Ogden', '/wiki/Commonly_misspelled_words']
# next None
# next ['/wiki/Chinese_language', '/wiki/Standard_Chinese_(language)']
# next None
# next ['/wiki/Basic_English', '/wiki/Constructed_language', '/wiki/Special_English']
# next None
# next None
# next None
# next None
# next None
# next None
# next ['/wiki/Basic_English']
# next None
# next None
# next ['/wiki/Wikipedia:Word_frequency', '/wiki/Wikipedia:Basic_English_alphabetical_wordlist', '/wiki/Commonly_misspelled_words', '/wiki/Glossary']
# next None
# next ['/wiki/Wikipedia:BASIC_English_ordered_wordlist', '/wiki/Wikipedia:BASIC_English_combined_wordlist', '/wiki/Wikipedia:BASIC_English_international_wordlist', '/wiki/BASIC_English', '/wiki/Charles_Kay_Ogden', '/wiki/Commonly_misspelled_words']
# next ['/wiki/Chinese_language', '/wiki/Standard_Chinese_(language)']
# next None
# next None
# next ['/wiki/Basic_English', '/wiki/Constructed_language', '/wiki/Special_English']
# next None
# next None
# next None
# next None
# next None
# next None
# next ['/wiki/Basic_English']
# next None
# next None
# next ['/wiki/Wikipedia:Word_frequency', '/wiki/Wikipedia:Basic_English_alphabetical_wordlist', '/wiki/Commonly_misspelled_words', '/wiki/Glossary']
# next None
# next ['/wiki/Wikipedia:BASIC_English_ordered_wordlist', '/wiki/Wikipedia:BASIC_English_combined_wordlist', '/wiki/Wikipedia:BASIC_English_international_wordlist', '/wiki/BASIC_English', '/wiki/Charles_Kay_Ogden', '/wiki/Commonly_misspelled_words']
# next ['/wiki/Chinese_language', '/wiki/Standard_Chinese_(language)']
# next None
# next None
# next ['/wiki/Basic_English', '/wiki/Constructed_language', '/wiki/Special_English']
# next None
# next None
# next ['/wiki/Received_Pronunciation']
# next None
# next None
# next None
# next None
# next ['/wiki/Basic_English']
# Overall visited 51 {'/wiki/Phonology', '/wiki/Chinese_language', '/wiki/Languages_of_Andorra', '/wiki/Languages_of_Morocco', '/wiki/Simplified_English', '/wiki/English_as_a_foreign_language', '/wiki/Orthography', '/wiki/Languages_of_Canada', '/wiki/Languages_of_Russia', '/wiki/Languages_of_Spain', '/wiki/Languages_of_South_Africa', '/wiki/Languages_of_New_Zealand', '/wiki/Languages_of_Papua_New_Guinea', '/wiki/Second_language', '/wiki/Template_talk:Languages_of_Countries', '/wiki/Languages_of_Pakistan', '/wiki/Plain_English_Campaign', '/wiki/Mandarin_Chinese', '/wiki/Wikipedia:List_of_simple_adjectives', '/wiki/Wikipedia:List_of_simple_verbs', '/wiki/Semantics', '/wiki/Historical_linguistics', '/wiki/Sign_language', '/wiki/Wikipedia:Basic_English_international_wordlist', '/wiki/Singlish', '/wiki/Tamil_language', '/wiki/Basic_English', '/wiki/Linguistics', '/wiki/Wikipedia:Basic_English_alphabetical_wordlist', '/wiki/Languages_of_Malta', '/wiki/Wikipedia:Basic_English_compound_wordlist', '/wiki/Languages_of_Ireland', '/wiki/Alphabet', '/wiki/List_of_languages', '/wiki/Languages_of_Nigeria', '/wiki/Languages_of_Iran', '/wiki/Languages_of_India', '/wiki/International_auxiliary_language', '/wiki/Wikipedia:Basic_English_combined_wordlist', '/wiki/Languages_of_Japan', '/wiki/English_Language', '/wiki/Wikipedia:Basic_English_ordered_wordlist', '/wiki/Template:Languages_of_Countries', '/wiki/Languages_of_Afghanistan', '/wiki/English_language', '/wiki/Wikipedia:Basic_English_picture_wordlist', '/wiki/Languages_of_Singapore', '/wiki/Fran%C3%A7ais_fondamental', '/wiki/Languages_of_Australia', '/wiki/Language_families_and_languages', '/wiki/Malay_language'}
